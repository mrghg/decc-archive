# %%
from agage_archive.io import read_nc

# %%
ds = read_nc("decc", "ch4", "HFD", "Picarro")
# Out:
# ... opening /Users/chxmr/code/decc-archive/data/decc/data-nc.zip/DECC-Picarro_HFD_ch4.nc

# %%
ds.mf.plot()
